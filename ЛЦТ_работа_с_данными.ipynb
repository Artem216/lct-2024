# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_excel('/content/ЛЦТ_описание.xlsx')
df
# Out:
#                           Поле  \
# 0                       gender
# 1                          age
# 2                reg_region_nm
# 3                cnt_tr_all_3m
# 4             cnt_tr_top_up_3m
# 5               cnt_tr_cash_3m
# 6                cnt_tr_buy_3m
# 7             cnt_tr_mobile_3m
# 8                cnt_tr_oil_3m
# 9            cnt_tr_on_card_3m
# 10           cnt_tr_service_3m
# 11                  cnt_zp_12m
# 12                  sum_zp_12m
# 13        limit_exchange_count
# 14   max_outstanding_amount_6m
# 15   avg_outstanding_amount_3m
# 16                 cnt_dep_act
# 17                 sum_dep_now
# 18  avg_dep_avg_balance_1month
# 19  max_dep_avg_balance_3month
# 20             app_vehicle_ind
# 21        app_position_type_nm
# 22              visit_purposes
# 23  qnt_months_from_last_visit
# 24                 super_clust
#
#                                                                        Описание
# ...

# %%
df = pd.read_excel('/content/ЛЦТ.xlsx')
df
# Out:
#      gender        age                             reg_region_nm  \
# 0       0.0  52.688172  Ханты-Мансийский автономный округ - Югра
# 1       0.0  26.940860          Республика Татарстан (Татарстан)
# 2       0.0  47.419355                     Город Санкт-Петербург
# 3       NaN  49.551075          Республика Татарстан (Татарстан)
# 4       NaN  55.591398                                       NaN
# ..      ...        ...                                       ...
# 995     1.0  23.083333                       Воронежская область
# 996     NaN  51.922043                      Свердловская область
# 997     NaN  66.104839            Чувашская республика - Чувашия
# 998     0.0  31.494624                      Белгородская область
# 999     0.0  39.357527                       Республика Калмыкия
#
#      cnt_tr_all_3m  cnt_tr_top_up_3m  cnt_tr_cash_3m  cnt_tr_buy_3m  \
# 0            201.0              18.0             6.0           97.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      576 non-null    float64
#  1   age                         999 non-null    float64
#  2   reg_region_nm               973 non-null    object
#  3   cnt_tr_all_3m               477 non-null    float64
#  4   cnt_tr_top_up_3m            477 non-null    float64
#  5   cnt_tr_cash_3m              477 non-null    float64
#  6   cnt_tr_buy_3m               477 non-null    float64
#  7   cnt_tr_mobile_3m            477 non-null    float64
#  8   cnt_tr_oil_3m               477 non-null    float64
#  9   cnt_tr_on_card_3m           477 non-null    float64
#  10  cnt_tr_service_3m           477 non-null    float64
#  11  cnt_zp_12m                  213 non-null    float64
#  12  sum_zp_12m                  213 non-null    float64
# ...

# %%
df = pd.read_excel('/content/ЛЦТ_каналы_продукты.xlsx')
df
# Out:
#                                                                       Продукт  \
# 0                                                                          ПК
# 1                                                                       TOPUP
# 2                                                                       REFIN
# 3                                                                          CC
# 4                                                                        AUTO
# 5                                                                    AUTO_SCR
# 6                                                                       MORTG
# 7                                                                 MORTG_REFIN
# 8                                                                   MORTG_SCR
# 9                                                                     DEPOSIT
# 10                                                                   SAVE_ACC
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Продукт     23 non-null     object
#  1   Описание    22 non-null     object
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  0 non-null      float64
#  4   Канал       8 non-null      object
#  5   Описание.1  8 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 1.2+ KB
